# %% [markdown]
# # **Import Library yang diperlukan**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings

filterwarnings('ignore')

# %% [markdown]
# # **Membuat Dataset CSV**

# %%
csv = pd.read_csv('/content/Netflix Revenue.csv')
csv.head()
# Out:
#          Date  Global Revenue  UACN Revenue  EMEA Revenue  LATM Revenue  \
# 0  31-03-2012       869791000           NaN           NaN           NaN
# 1  30-06-2012       889163000           NaN           NaN           NaN
# 2  30-09-2012       905089000           NaN           NaN           NaN
# 3  31-12-2012       945239000           NaN           NaN           NaN
# 4  31-03-2013      1023961000           NaN           NaN           NaN
#
#    APAC Revenue  UACN Members  EMEA  Members  LATM Members  APAC Members  ...  \
# 0           NaN           NaN            NaN           NaN           NaN  ...
# 1           NaN           NaN            NaN           NaN           NaN  ...
# 2           NaN           NaN            NaN           NaN           NaN  ...
# 3           NaN           NaN            NaN           NaN           NaN  ...
# 4           NaN           NaN            NaN           NaN           NaN  ...
#
#    EMEA RPU  LATM  RPU  APAC  RPU  Domestic Members  Domestic Revenue  \
# 0       NaN        NaN        NaN       506665000.0       506665000.0
# 1       NaN        NaN        NaN       532705000.0       532705000.0
# 2       NaN        NaN        NaN       556027000.0       556027000.0
# 3       NaN        NaN        NaN       589471000.0       589471000.0
# 4       NaN        NaN        NaN       638649000.0       638649000.0
#
#    International Members  International Revenue  Domestic Free Trialers  \
# 0              2409000.0             43425000.0                     NaN
# 1              3024000.0             64973000.0                     NaN
# 2              3689000.0             77744000.0                     NaN
# 3              4892000.0            101400000.0                     NaN
# 4              6331000.0            142019000.0                     NaN
#
#    Interntaional Free Trialers  Netflix Global Users
# 0                          NaN          50,90,74,000
# 1                          NaN          53,57,29,000
# 2                          NaN          55,97,16,000
# 3                          NaN          59,43,63,000
# 4                          NaN          64,49,80,000
#
# [5 rows x 21 columns]

# %% [markdown]
# # **Memuat Dataset**

# %%
csv.columns
# Out:
# Index(['Date', 'Global Revenue', 'UACN Revenue', 'EMEA Revenue',
#        'LATM Revenue', 'APAC Revenue', 'UACN Members', 'EMEA  Members',
#        'LATM Members', 'APAC Members', 'UACN RPU', 'EMEA RPU', 'LATM  RPU',
#        'APAC  RPU', 'Domestic Members', 'Domestic Revenue',
#        'International Members', 'International Revenue',
#        'Domestic Free Trialers', 'Interntaional Free Trialers',
#        'Netflix Global Users'],
#       dtype='object')

# %%
csv.shape
# Out:
# (45, 21)

# %% [markdown]
# The columns in the dataset include:
#
# Date: The date corresponding to the metrics recorded.
#
# Global Revenue: The total revenue generated by Netflix globally.
#
# UACN Revenue: The revenue generated by Netflix from the UACN region.
#
# EMEA Revenue: The revenue generated by Netflix from the EMEA (Europe, Middle East, and Africa) region.
#
# LATM Revenue: The revenue generated by Netflix from the LATM (Latin America) region.
#
# APAC Revenue: The revenue generated by Netflix from the APAC (Asia-Pacific) region.
#
# UACN Members: The number of Netflix members in the UACN region.
#
# EMEA Members: The number of Netflix members in the EMEA region.
#
# LATM Members: The number of Netflix members in the LATM region.
#
# APAC Members: The number of Netflix members in the APAC region.
#
# EMEA RPU: Revenue per user (RPU) in the EMEA region.
#
# LATM RPU: Revenue per user (RPU) in the LATM region.
#
# APAC RPU: Revenue per user (RPU) in the APAC region.
#
# Domestic Members: The number of Netflix members in the
# domestic market.
#
# Domestic Revenue: The revenue generated by Netflix in the domestic market.
#
# International Members: The number of Netflix members in the international market.
#
# International Revenue: The revenue generated by Netflix in the international market.
#
# Domestic Free Trialers: The number of Netflix free trial users in the domestic market.
#
# International Free Trialers: The number of Netflix free trial users in the international market.
#
# Netflix Global Users: The total number of Netflix users worldwide

# %% [markdown]
# # **Missing Values**

# %%
csv.isna().sum()
# Out:
# Date                            0
# Global Revenue                  0
# UACN Revenue                   28
# EMEA Revenue                   28
# LATM Revenue                   28
# APAC Revenue                   28
# UACN Members                   28
# EMEA  Members                  28
# LATM Members                   28
# APAC Members                   28
# UACN RPU                       28
# EMEA RPU                       28
# LATM  RPU                      28
# APAC  RPU                      28
# Domestic Members               17
# Domestic Revenue               17
# International Members          17
# International Revenue          17
# Domestic Free Trialers         33
# Interntaional Free Trialers    33
# Netflix Global Users            0
# dtype: int64

# %%
csv.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# dtype: bool

# %%
# Remove commas and convert 'Netflix Global Users' column to numeric
csv['Netflix Global Users'] = csv['Netflix Global Users'].str.replace(',','').astype(float)

# Extract the year from the 'Date' column
csv['Year'] = pd.to_datetime(csv['Date']).dt.year

# %%
csv
# Out:
#          Date  Global Revenue  UACN Revenue  EMEA Revenue  LATM Revenue  \
# 0  2012-03-31       869791000           NaN           NaN           NaN
# 1  2012-06-30       889163000           NaN           NaN           NaN
# 2  2012-09-30       905089000           NaN           NaN           NaN
# 3  2012-12-31       945239000           NaN           NaN           NaN
# 4  2013-03-31      1023961000           NaN           NaN           NaN
# 5  2013-06-30      1069372000           NaN           NaN           NaN
# 6  2013-09-30      1105999000           NaN           NaN           NaN
# 7  2013-12-31      1175230000           NaN           NaN           NaN
# 8  2014-03-31      1270089000           NaN           NaN           NaN
# 9  2014-06-30      1340407000           NaN           NaN           NaN
# 10 2014-09-30      1409432000           NaN           NaN           NaN
# 11 2014-12-31      1484728000           NaN           NaN           NaN
# 12 2015-03-31      1573129000           NaN           NaN           NaN
# 13 2015-06-30      1644694000           NaN           NaN           NaN
# 14 2015-09-30      1738355000           NaN           NaN           NaN
# 15 2015-12-31      1823333000           NaN           NaN           NaN
# 16 2016-03-31      1957736000           NaN           NaN           NaN
# 17 2016-06-30      2105204000           NaN           NaN           NaN
# 18 2016-09-30      2290188000           NaN           NaN           NaN
# 19 2016-12-31      2477541000           NaN           NaN           NaN
# 20 2017-03-31      2636635000           NaN           NaN           NaN
# 21 2017-06-30      2785464000           NaN           NaN           NaN
# 22 2017-09-30      2984859000           NaN           NaN           NaN
# 23 2017-12-31      3285755000           NaN           NaN           NaN
# 24 2018-03-31      3700856000           NaN           NaN           NaN
# 25 2018-06-30      3907270000           NaN           NaN           NaN
# 26 2018-09-30      3999374000           NaN           NaN           NaN
# 27 2018-12-31      4186841000           NaN           NaN           NaN
# 28 2019-03-31      4520992000  2.256851e+09  1.233379e+09  6.304720e+08
# 29 2019-06-30      4923116000  2.501199e+09  1.319087e+09  6.771360e+08
# 30 2019-09-30      5244905000  2.621250e+09  1.428040e+09  7.414340e+08
# 31 2019-12-31      5467434000  2.671908e+09  1.562561e+09  7.463920e+08
# 39   870705000.0    75215000.0     74036000.0    39961000.0    32632000.0
# 40   916754000.0    74579000.0     73733000.0    39610000.0    33719000.0
# 41   907719000.0    73283000.0     72966000.0    39624000.0    34799000.0
# 42   889037000.0    73387000.0     73534000.0    39936000.0    36228000.0
# 43   856711000.0    74296000.0     76729000.0    41699000.0    38023000.0
# 44   933523000.0    74398000.0     77373000.0    41249000.0    39478000.0
#
#     ...  LATM  RPU  APAC  RPU  Domestic Members  Domestic Revenue  \
# 0   ...        NaN        NaN      5.066650e+08      5.066650e+08
# 1   ...        NaN        NaN      5.327050e+08      5.327050e+08
# 2   ...        NaN        NaN      5.560270e+08      5.560270e+08
# 3   ...        NaN        NaN      5.894710e+08      5.894710e+08
# 4   ...        NaN        NaN      6.386490e+08      6.386490e+08
# 5   ...        NaN        NaN      6.710890e+08      6.710890e+08
# 6   ...        NaN        NaN      7.010830e+08      7.010830e+08
# 7   ...        NaN        NaN      7.405540e+08      7.405540e+08
# 8   ...        NaN        NaN      7.986170e+08      7.986170e+08
# 9   ...        NaN        NaN      8.382250e+08      8.382250e+08
# 10  ...        NaN        NaN      8.771500e+08      8.771500e+08
# 11  ...        NaN        NaN      9.174420e+08      9.174420e+08
# 12  ...        NaN        NaN      9.845320e+08      9.845320e+08
# 13  ...        NaN        NaN      1.025913e+09      1.025913e+09
# 14  ...        NaN        NaN      1.063961e+09      1.063961e+09
# 15  ...        NaN        NaN      1.105933e+09      1.105933e+09
# 16  ...        NaN        NaN      1.161241e+09      1.161241e+09
# 17  ...        NaN        NaN      1.208271e+09      1.208271e+09
# 18  ...        NaN        NaN      1.304333e+09      1.304333e+09
# 19  ...        NaN        NaN      1.403462e+09      1.403462e+09
# 20  ...        NaN        NaN      1.046199e+09      1.046199e+09
# 21  ...        NaN        NaN      1.165228e+09      1.165228e+09
# 22  ...        NaN        NaN      1.327435e+09      1.327435e+09
# 23  ...        NaN        NaN      1.550329e+09      1.550329e+09
# 24  ...        NaN        NaN      1.820019e+09      1.820019e+09
# 25  ...        NaN        NaN      1.893222e+09      1.893222e+09
# 26  ...        NaN        NaN      1.937314e+09      1.937314e+09
# 27  ...        NaN        NaN      1.996092e+09      1.996092e+09
# 28  ...       7.84       9.37               NaN               NaN
# 29  ...       8.14       9.29               NaN               NaN
# 30  ...       8.63       9.29               NaN               NaN
# 31  ...       8.18       9.07               NaN               NaN
# 32  ...       8.05       8.94               NaN               NaN
# 33  ...       7.44       8.96               NaN               NaN
# 34  ...       7.27       9.20               NaN               NaN
# 35  ...       7.12       9.32               NaN               NaN
# 36  ...       7.39       9.71               NaN               NaN
# 37  ...       7.50       9.74               NaN               NaN
# 38  ...       7.86       9.60               NaN               NaN
# 39  ...       8.14       9.26               NaN               NaN
# 40  ...       8.37       9.21               NaN               NaN
# 41  ...       8.67       8.83               NaN               NaN
# 42  ...       8.58       8.34               NaN               NaN
# 43  ...       8.30       7.69               NaN               NaN
# 44  ...       8.60       8.03               NaN               NaN
#
#     International Members  International Revenue  Domestic Free Trialers  \
# 0               2409000.0           4.342500e+07                     NaN
# 1               3024000.0           6.497300e+07                     NaN
# 2               3689000.0           7.774400e+07                     NaN
# 3               4892000.0           1.014000e+08                     NaN
# 33                          NaN          1.929470e+08  2020
# 34                          NaN          1.951510e+08  2020
# 35                          NaN          2.036630e+08  2020
# 36                          NaN          2.076390e+08  2021
# 37                          NaN          2.091800e+08  2021
# 38                          NaN          2.135630e+08  2021
# 39                          NaN          2.218440e+08  2021
# 40                          NaN          2.216410e+08  2022
# 41                          NaN          2.206720e+08  2022
# 42                          NaN          2.230850e+08  2022
# 43                          NaN          2.307470e+08  2022
# 44                          NaN          2.324980e+08  2023
#
# [45 rows x 22 columns]

# %%
csv.describe()
# Out:
#        Global Revenue  UACN Revenue  EMEA Revenue  LATM Revenue  APAC Revenue  \
# count    4.500000e+01  1.700000e+01  1.700000e+01  1.700000e+01  1.700000e+01
# mean     3.804736e+09  3.068941e+09  2.075164e+09  8.629001e+08  6.830686e+08
# std      2.559212e+09  4.209004e+08  4.594011e+08  1.349618e+08  2.204141e+08
# min      8.697910e+08  2.256851e+09  1.233379e+09  6.304720e+08  3.196020e+08
# 25%      1.484728e+09  2.702776e+09  1.723474e+09  7.853680e+08  4.836600e+08
# 50%      2.984859e+09  3.170972e+09  2.343674e+09  8.366470e+08  7.624140e+08
# 75%      6.148286e+09  3.350424e+09  2.432239e+09  9.989480e+08  8.707050e+08
# max      8.161503e+09  3.608645e+09  2.561831e+09  1.070192e+09  9.335230e+08
#
#        UACN Members  EMEA  Members  LATM Members  APAC Members   UACN RPU  \
# count  1.700000e+01   1.700000e+01  1.700000e+01  1.700000e+01  17.000000
# mean   7.207747e+07   6.418447e+07  3.635882e+07  2.628129e+07  14.200588
# std    3.129072e+06   1.149417e+07  4.624148e+06  8.939004e+06   1.432919
# min    6.650100e+07   4.254200e+07  2.754700e+07  1.214100e+07  11.450000
# 25%    6.996900e+07   5.873400e+07  3.431800e+07  1.983500e+07  13.220000
# 50%    7.338700e+07   6.850800e+07  3.789400e+07  2.685300e+07  14.250000
# 75%    7.429600e+07   7.353400e+07  3.962400e+07  3.371900e+07  14.910000
# max    7.521500e+07   7.737300e+07  4.169900e+07  3.947800e+07  16.370000
#
#        ...  LATM  RPU  APAC  RPU  Domestic Members  Domestic Revenue  \
# count  ...  17.000000  17.000000      2.800000e+01      2.800000e+01
# mean   ...   8.004706   9.050000      1.084327e+09      1.084327e+09
# std    ...   0.508123   0.562361      4.402810e+08      4.402810e+08
# min    ...   7.120000   7.690000      5.066650e+08      5.066650e+08
# 25%    ...   7.500000   8.940000      7.306862e+08      7.306862e+08
# 50%    ...   8.140000   9.210000      1.036056e+09      1.036056e+09
# 75%    ...   8.370000   9.320000      1.310108e+09      1.310108e+09
# max    ...   8.670000   9.740000      1.996092e+09      1.996092e+09
#
#        International Members  International Revenue  Domestic Free Trialers  \
# count           2.800000e+01           2.800000e+01            1.200000e+01
# mean            2.956664e+07           7.265650e+08            1.498000e+06
# std             2.372401e+07           6.444257e+08            2.989615e+05
# min             2.409000e+06           4.342500e+07            1.018000e+06
# 25%             9.312500e+06           2.118262e+08            1.378250e+06
# 50%             2.280000e+07           4.858165e+08            1.493000e+06
# 75%             4.591925e+07           1.075956e+09            1.603000e+06
# max             8.077300e+07           2.105592e+09            2.065000e+06
#
#        Interntaional Free Trialers  Netflix Global Users         Year
# count                 1.200000e+01          4.500000e+01    45.000000
# mean                  3.873833e+06          7.682303e+08  2017.133333
# std                   1.435152e+06          5.773021e+08     3.286335
# min                   2.156000e+06          1.488630e+08  2012.000000
# 25%                   2.814500e+06          2.206720e+08  2014.000000
# 50%                   3.558000e+06          6.781030e+08  2017.000000
# 75%                   4.605750e+06          1.133371e+09  2020.000000
# max                   7.131000e+06          2.076865e+09  2023.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# # **Pendapatan Global Netflix dari Waktu ke Waktu**

# %%
# Convert the 'Date' column to datetime format
csv['Date'] = pd.to_datetime(csv['Date'])

# %%
# Sort the dataframe by date
csv = csv.sort_values('Date')

# Plot the revenue trends over time
plt.figure(figsize=(10,5))
plt.grid()
plt.plot(csv['Date'], csv['Global Revenue'])
plt.xlabel('Year', fontsize=12)
plt.ylabel('Revenue', fontsize=12)
plt.title('Global Revenue', fontsize=14)
plt.xticks(rotation=35)

# Modify the y-axis tick labels
plt.gca().get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,.2f}".format(x)))

# %% [markdown]
# # **Rata-rata pengguna netflix global tiap tahun**

# %%
# Group the data by year and calculate the average global users
Average_Users = csv.groupby('Year')['Netflix Global Users'].mean()
Average_Users
# Out:
# Year
# 2012    5.497205e+08
# 2013    6.956315e+08
# 2014    8.718158e+08
# 2015    1.068170e+09
# 2016    1.305294e+09
# 2017    1.323351e+09
# 2018    1.983274e+09
# 2019    1.564622e+08
# 2020    1.936542e+08
# 2021    2.130565e+08
# 2022    2.240362e+08
# 2023    2.324980e+08
# Name: Netflix Global Users, dtype: float64

# %%
# Plot the average global users over time
plt.figure(figsize=(10,6))
plt.grid()
plt.plot(Average_Users.index, Average_Users.values)
plt.title('Average Netflix Global Users by Year')
plt.xlabel('Year')
plt.ylabel('Average Global Users')
plt.xticks(rotation=0)


# Modify the y-axis tick labels
plt.gca().get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,.2f}".format(x)))

# %% [markdown]
# # **Netflix Global Users Trend**

# %%
# Sort the data by date
csv.sort_values('Date')

# Plot the global users trend over time
plt.figure(figsize=(10,5))
plt.grid(True)
plt.plot(csv['Date'], csv['Netflix Global Users'])
plt.title('Netflix Global Users Trend by Year', fontsize=14)
plt.xlabel('Year', fontsize=10)
plt.ylabel('Netflix Global Users', fontsize=10)
plt.xticks(rotation=0)

# Modify the y-axis tick labels
plt.gca().get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,.2f}".format(x)))

# %% [markdown]
# # **Pendapatan berdasarkan Wilayah**

# %%
# Drop rows with missing values in the revenue columns
csv_clean = csv.dropna(subset=['UACN Revenue', 'EMEA Revenue', 'LATM Revenue', 'APAC Revenue' ])

# Calculate the sum of revenue by region
revenue_by_region = csv_clean[['UACN Revenue', 'EMEA Revenue', 'LATM Revenue', 'APAC Revenue']].sum()

revenue_by_region
# Out:
# UACN Revenue    5.217199e+10
# EMEA Revenue    3.527779e+10
# LATM Revenue    1.466930e+10
# APAC Revenue    1.161217e+10
# dtype: float64

# %%
# Plot the bar chart of revenue by region
plt.figure(figsize=(10, 5))
revenue_by_region.plot(kind = 'bar', color='pink')
plt.title('Revenue by Region', fontsize=16)
plt.xlabel('Region', fontsize=12)
plt.ylabel('Revenue', fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis='y')

# Modify the y-axis tick labels
plt.gca().get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,.2f}".format(x)))
